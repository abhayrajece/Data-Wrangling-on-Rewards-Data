# %%
import pandas as pd

# %%
df= pd.read_csv(r'C:\Users\Abhay Raj\OneDrive - DXC Production\Desktop\Data wrangling project\RewardsData.csv')

# %%
df.head(20)
# Out:
#     User ID  Birthdate           City           State    Zip  \
# 0         1  1/31/1992   Minneapolis          Georgia  55401
# 1         2        NaN   Los Angeles         Colorado  90210
# 2         3  1/11/1990         Merida              AL  97204
# 3         4  4/16/1990  Winston-Salem              NC  27106
# 4         5  3/24/1994  Winston-Salem              NC  27109
# 5         6  10/9/1995              G              AL  85588
# 6         7  9/22/1995            NaN             NaN    NaN
# 7         8        NaN            NaN             NaN    NaN
# 8         9        NaN            NaN             NaN    NaN
# 9        10  7/20/1999  Winston Salem              NC  27106
# 10       11  7/22/2000            NaN             NaN    NaN
# 11       12        NaN            NaN             NaN    NaN
# 12       13        NaN            NaN             NaN    NaN
# 13       14  11/1/2000  Winston-Salem              NC  27106
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7252 entries, 0 to 7251
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   User ID              7252 non-null   int64
#  1   Birthdate            1172 non-null   object
#  2   City                 330 non-null    object
#  3   State                330 non-null    object
#  4   Zip                  330 non-null    object
#  5   Available Points     7252 non-null   int64
#  6   Total Points Earned  7252 non-null   int64
#  7   Points Spent         7252 non-null   int64
#  8   Joined On            7252 non-null   object
#  9   Last Seen            7031 non-null   object
#  10  Tags                 7252 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 623.3+ KB

# %%
df.describe()
# Out:
#            User ID  Available Points  Total Points Earned  Points Spent
# count  7252.000000       7252.000000           7252.00000   7252.000000
# mean   3621.871484       1406.701737           1596.89203    191.383067
# std    2091.085954       2031.637229           2531.73693   1223.108659
# min       1.000000          0.000000            100.00000      0.000000
# 25%    1811.750000        400.000000            400.00000      0.000000
# 50%    3619.500000        735.000000            800.00000      0.000000
# 75%    5432.250000       1550.000000           1710.00000      0.000000
# max    7242.000000      52165.000000          59525.00000  57800.000000

# %%
df.isna()
# Out:
#       User ID  Birthdate   City  State    Zip  Available Points  \
# 0       False      False  False  False  False             False
# 1       False       True  False  False  False             False
# 2       False      False  False  False  False             False
# 3       False      False  False  False  False             False
# 4       False      False  False  False  False             False
# ...       ...        ...    ...    ...    ...               ...
# 7247    False       True   True   True   True             False
# 7248    False       True   True   True   True             False
# 7249    False      False   True   True   True             False
# 7250    False       True   True   True   True             False
# 7251    False       True   True   True   True             False
#
#       Total Points Earned  Points Spent  Joined On  Last Seen   Tags
# 0                   False         False      False      False  False
# ...

# %%
#getting sum of missing values for each column
missing_value_count = df.isna().sum()

# %%
missing_value_count
# Out:
# User ID                   0
# Birthdate              6080
# City                   6922
# State                  6922
# Zip                    6922
# Available Points          0
# Total Points Earned       0
# Points Spent              0
# Joined On                 0
# Last Seen               221
# Tags                      0
# dtype: int64

# %%
len(df)
# Out:
# 7252

# %%
#checking % of missing data for every column
missing_value_percent = missing_value_count / len(df) *100

# %%
missing_value_percent
# Out:
# User ID                 0.000000
# Birthdate              83.838941
# City                   95.449531
# State                  95.449531
# Zip                    95.449531
# Available Points        0.000000
# Total Points Earned     0.000000
# Points Spent            0.000000
# Joined On               0.000000
# Last Seen               3.047435
# Tags                    0.000000
# dtype: float64

# %%
df['Last Seen']
# Out:
# 0       12/16/2021 17:42
# 1        4/13/2022 14:28
# 2        4/21/2021 10:54
# 3        6/30/2022 22:22
# 4       12/30/2020 10:57
#               ...
# 7247     6/30/2022 12:04
# 7248     6/28/2022 22:43
# 7249     6/30/2022 12:48
# 7250     6/30/2022 20:39
# 7251       7/1/2022 2:42
# Name: Last Seen, Length: 7252, dtype: object

# %%
#changeing the data type of Last Seen from object to date and time
df["Last Seen"] = pd.to_datetime(df["Last Seen"])
df["Last Seen"]
# Out:
# 0      2021-12-16 17:42:00
# 1      2022-04-13 14:28:00
# 2      2021-04-21 10:54:00
# 3      2022-06-30 22:22:00
# 4      2020-12-30 10:57:00
#                ...
# 7247   2022-06-30 12:04:00
# 7248   2022-06-28 22:43:00
# 7249   2022-06-30 12:48:00
# 7250   2022-06-30 20:39:00
# 7251   2022-07-01 02:42:00
# Name: Last Seen, Length: 7252, dtype: datetime64[ns]

# %%
print(df["Last Seen"].max())
print (df["Last Seen"].min())
# Out:
# 2022-07-01 08:36:00
# 2020-10-12 14:38:00

# %%
#replaceing NaN with starting date in Last seen column
df["Last Seen"].fillna(value=df["Last Seen"].min(), inplace=True)

# %%
df.isna().sum()
# Out:
# User ID                   0
# Birthdate              6080
# City                   6922
# State                  6922
# Zip                    6922
# Available Points          0
# Total Points Earned       0
# Points Spent              0
# Joined On                 0
# Last Seen                 0
# Tags                      0
# dtype: int64

# %%
#Dropping all those rows where NaN is present in any feature
df_sample = df.dropna()
df_sample
# Out:
#       User ID  Birthdate           City           State    Zip  \
# 0           1  1/31/1992   Minneapolis          Georgia  55401
# 2           3  1/11/1990         Merida              AL  97204
# 3           4  4/16/1990  Winston-Salem              NC  27106
# 4           5  3/24/1994  Winston-Salem              NC  27109
# 5           6  10/9/1995              G              AL  85588
# ...       ...        ...            ...             ...    ...
# 7228     7219  6/12/2004    Lutherville        Maryland  21093
# 7229     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7236     7227  3/14/2000       Clemmons  North Carolina  27012
# 7239     7230  5/18/1999  Winston Salem  North Carolina  27107
# 7244     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#       Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                  300                  300             0     9/4/2020 0:15
# ...

# %%
df_sample.isna().sum()
# Out:
# User ID                0
# Birthdate              0
# City                   0
# State                  0
# Zip                    0
# Available Points       0
# Total Points Earned    0
# Points Spent           0
# Joined On              0
# Last Seen              0
# Tags                   0
# dtype: int64

# %%
#Dropping Tags Colmun.
df_sample = df_sample.drop(columns = "Tags")

# %%
df_sample
# Out:
#       User ID  Birthdate           City           State    Zip  \
# 0           1  1/31/1992   Minneapolis          Georgia  55401
# 2           3  1/11/1990         Merida              AL  97204
# 3           4  4/16/1990  Winston-Salem              NC  27106
# 4           5  3/24/1994  Winston-Salem              NC  27109
# 5           6  10/9/1995              G              AL  85588
# ...       ...        ...            ...             ...    ...
# 7228     7219  6/12/2004    Lutherville        Maryland  21093
# 7229     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7236     7227  3/14/2000       Clemmons  North Carolina  27012
# 7239     7230  5/18/1999  Winston Salem  North Carolina  27107
# 7244     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#       Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                  300                  300             0     9/4/2020 0:15
# ...

# %%
#Checking the City columns uniue values
city_unique_values = df_sample["City"].unique()
city_unique_values.sort()
city_unique_values
# Out:
# array(['Atlanta', 'Aurora ', 'Austin', 'Bakersfield', 'Belmont ',
#        'Bethesda ', 'Bourne', 'Chapel Hill', 'Charlotte', 'Charlotte ',
#        'Clemmons', 'Cleveland', 'Clovis', 'Dallas', 'Delhi', 'Delran',
#        'Downers Grove', 'Durham', 'Duxbury', 'Edina', 'Fort Myers ', 'G',
#        'Gainesville', 'Greensboro', 'Guaynabo', 'Huntersville',
#        'Indian Trail', 'Jacksonville ', 'Jamesville', 'Larchmont',
#        'Libertyville', 'Lincoln University', 'Littleton', 'Lmao',
#        'Locust', 'Louisville', 'Lutherville', 'Malvern',
#        'Manhattan beach ', 'Marblehead', 'Memphis', 'Merida', 'Milwaukee',
#        'Minneapolis ', 'Mooresville', 'Morganton', 'Mt. Pleasant ',
#        'Nashville', 'Northport', 'Oakwood', 'Orleans ', 'Ormond Beach',
#        'Palm Beach Gardens', 'Palmetto Bay', 'Perry', 'Pittsburgh', 'Rex',
#        'Rocky hill', 'Rome', 'San Marcos', 'Sharon', 'Smithtown',
#        'Summit', 'Supply', 'Terrace Park', 'Thomasville', 'Valrico ',
# ...

# %%
#Replacing all similar city name, in this case WInston Salem
df_sample.replace(to_replace = ['Winston Salem', 'Winston Salem ',
       'Winston salem', 'Winston salem ', 'Winston-Salem',
       'Winston-Salem ', 'Winston-Salem, NC', 'Winston-salem'], value= 'Winston-Salem', inplace= True)

# %%
#Checking again after repalcin.
city_unique_values = df_sample["City"].unique()
city_unique_values.sort()
city_unique_values
# Out:
# array(['Atlanta', 'Aurora ', 'Austin', 'Bakersfield', 'Belmont ',
#        'Bethesda ', 'Bourne', 'Chapel Hill', 'Charlotte', 'Charlotte ',
#        'Clemmons', 'Cleveland', 'Clovis', 'Dallas', 'Delhi', 'Delran',
#        'Downers Grove', 'Durham', 'Duxbury', 'Edina', 'Fort Myers ', 'G',
#        'Gainesville', 'Greensboro', 'Guaynabo', 'Huntersville',
#        'Indian Trail', 'Jacksonville ', 'Jamesville', 'Larchmont',
#        'Libertyville', 'Lincoln University', 'Littleton', 'Lmao',
#        'Locust', 'Louisville', 'Lutherville', 'Malvern',
#        'Manhattan beach ', 'Marblehead', 'Memphis', 'Merida', 'Milwaukee',
#        'Minneapolis ', 'Mooresville', 'Morganton', 'Mt. Pleasant ',
#        'Nashville', 'Northport', 'Oakwood', 'Orleans ', 'Ormond Beach',
#        'Palm Beach Gardens', 'Palmetto Bay', 'Perry', 'Pittsburgh', 'Rex',
#        'Rocky hill', 'Rome', 'San Marcos', 'Sharon', 'Smithtown',
#        'Summit', 'Supply', 'Terrace Park', 'Thomasville', 'Valrico ',
# ...

# %%
#Now removing all leading and trailing spaces from our rows
df_sample["City"]=df_sample["City"].str.strip()

# %%
city_unique_values = df_sample["City"].unique()
city_unique_values.sort()
city_unique_values
# Out:
# array(['Atlanta', 'Aurora', 'Austin', 'Bakersfield', 'Belmont',
#        'Bethesda', 'Bourne', 'Chapel Hill', 'Charlotte', 'Clemmons',
#        'Cleveland', 'Clovis', 'Dallas', 'Delhi', 'Delran',
#        'Downers Grove', 'Durham', 'Duxbury', 'Edina', 'Fort Myers', 'G',
#        'Gainesville', 'Greensboro', 'Guaynabo', 'Huntersville',
#        'Indian Trail', 'Jacksonville', 'Jamesville', 'Larchmont',
#        'Libertyville', 'Lincoln University', 'Littleton', 'Lmao',
#        'Locust', 'Louisville', 'Lutherville', 'Malvern',
#        'Manhattan beach', 'Marblehead', 'Memphis', 'Merida', 'Milwaukee',
#        'Minneapolis', 'Mooresville', 'Morganton', 'Mt. Pleasant',
#        'Nashville', 'Northport', 'Oakwood', 'Orleans', 'Ormond Beach',
#        'Palm Beach Gardens', 'Palmetto Bay', 'Perry', 'Pittsburgh', 'Rex',
#        'Rocky hill', 'Rome', 'San Marcos', 'Sharon', 'Smithtown',
#        'Summit', 'Supply', 'Terrace Park', 'Thomasville', 'Valrico',
# ...

# %%
#Making all words first letter as capital letter
df_sample["City"]=df_sample["City"].str.title()

# %%
city_unique_values = df_sample["City"].unique()
city_unique_values.sort()
city_unique_values
# Out:
# array(['Atlanta', 'Aurora', 'Austin', 'Bakersfield', 'Belmont',
#        'Bethesda', 'Bourne', 'Chapel Hill', 'Charlotte', 'Clemmons',
#        'Cleveland', 'Clovis', 'Dallas', 'Delhi', 'Delran', 'Dover',
#        'Downers Grove', 'Durham', 'Duxbury', 'Edina', 'Fort Myers', 'G',
#        'Gainesville', 'Greensboro', 'Guaynabo', 'Huntersville',
#        'Indian Trail', 'Jacksonville', 'Jamesville', 'Larchmont',
#        'Libertyville', 'Lincoln University', 'Littleton', 'Lmao',
#        'Locust', 'Louisville', 'Lutherville', 'Malvern',
#        'Manhattan Beach', 'Marblehead', 'Memphis', 'Merida', 'Milwaukee',
#        'Minneapolis', 'Mooresville', 'Morganton', 'Mt. Pleasant',
#        'Nashville', 'Northport', 'Oakwood', 'Orleans', 'Ormond Beach',
#        'Palm Beach Gardens', 'Palmetto Bay', 'Perry', 'Pittsburgh', 'Rex',
#        'Rocky Hill', 'Rome', 'San Marcos', 'Sharon', 'Smithtown',
#        'Summit', 'Supply', 'Terrace Park', 'Thomasville', 'Valrico',
# ...

# %%
#Checking all uniue values in states columns now
state_unique_values = df_sample['State'].unique()
state_unique_values.sort()
state_unique_values
# Out:
# array(['AL', 'CT', 'California', 'Colorado', 'Connecticut',
#        'District of Columbia', 'FL', 'Florida', 'GA', 'Georgia',
#        'Illinois', 'Kentucky', 'MA', 'MD', 'MN', 'Maryland',
#        'Massachusetts', 'NC', 'NJ', 'NY', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'OH', 'Ohio', 'PA', 'Pennsylvania',
#        'Puerto Rico', 'SC', 'TN', 'TX', 'Tennessee', 'Texas', 'WI'],
#       dtype=object)

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
us_state_to_abbrev
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
# ...

# %%
for state_name in us_state_to_abbrev:
    df_sample["State"].replace(to_replace = state_name, value = us_state_to_abbrev[state_name], inplace = True)

# %%
state_unique_values = df_sample['State'].unique()
state_unique_values.sort()
state_unique_values
# Out:
# array(['AL', 'CA', 'CO', 'CT', 'DC', 'FL', 'GA', 'IL', 'KY', 'MA', 'MD',
#        'MN', 'NC', 'NJ', 'NM', 'NY', 'OH', 'PA', 'PR', 'SC', 'TN', 'TX',
#        'WI'], dtype=object)

# %%
state_df = pd.DataFrame(list(us_state_to_abbrev.items()),columns = ['State Name', 'State'])

# %%
state_df
# Out:
#                               State Name State
# 0                                Alabama    AL
# 1                                 Alaska    AK
# 2                                Arizona    AZ
# 3                               Arkansas    AR
# 4                             California    CA
# 5                               Colorado    CO
# 6                            Connecticut    CT
# 7                               Delaware    DE
# 8                                Florida    FL
# 9                                Georgia    GA
# 10                                Hawaii    HI
# 11                                 Idaho    ID
# 12                              Illinois    IL
# 13                               Indiana    IN
# 14                                  Iowa    IA
# 15                                Kansas    KS
# 16                              Kentucky    KY
# 17                             Louisiana    LA
# 18                                 Maine    ME
# ...

# %%
df_sample = pd.merge(df_sample,state_df, on = 'State', how = 'left')

# %%
df_sample
# Out:
#      User ID  Birthdate           City State    Zip  Available Points  \
# 0          1  1/31/1992    Minneapolis    GA  55401               300
# 1          3  1/11/1990         Merida    AL  97204               330
# 2          4  4/16/1990  Winston-Salem    NC  27106             10790
# 3          5  3/24/1994  Winston-Salem    NC  27109               650
# 4          6  10/9/1995              G    AL  85588              7085
# ..       ...        ...            ...   ...    ...               ...
# 167     7219  6/12/2004    Lutherville    MD  21093               490
# 168     7220   8/7/1999  Winston-Salem    NC  27106               430
# 169     7227  3/14/2000       Clemmons    NC  27012               460
# 170     7230  5/18/1999  Winston-Salem    NC  27107               410
# 171     7235  6/20/2004       Guaynabo    PR    969               440
#
#      Total Points Earned  Points Spent         Joined On           Last Seen  \
# ...

# %%
df_sample.rename(columns = {'State':"State Abbreviation"}, inplace = True)
df_sample
# Out:
#      User ID  Birthdate           City State Abbreviation    Zip  \
# 0          1  1/31/1992    Minneapolis                 GA  55401
# 1          3  1/11/1990         Merida                 AL  97204
# 2          4  4/16/1990  Winston-Salem                 NC  27106
# 3          5  3/24/1994  Winston-Salem                 NC  27109
# 4          6  10/9/1995              G                 AL  85588
# ..       ...        ...            ...                ...    ...
# 167     7219  6/12/2004    Lutherville                 MD  21093
# 168     7220   8/7/1999  Winston-Salem                 NC  27106
# 169     7227  3/14/2000       Clemmons                 NC  27012
# 170     7230  5/18/1999  Winston-Salem                 NC  27107
# 171     7235  6/20/2004       Guaynabo                 PR    969
#
#      Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                 300                  300             0     9/4/2020 0:15
# ...

# %%
state_name_col = df_sample.pop('State Name')

# %%
df_sample.insert(3,'State Name', state_name_col)
df_sample.head()
# Out:
#    User ID  Birthdate           City      State Name State Abbreviation  \
# 0        1  1/31/1992    Minneapolis         Georgia                 GA
# 1        3  1/11/1990         Merida         Alabama                 AL
# 2        4  4/16/1990  Winston-Salem  North Carolina                 NC
# 3        5  3/24/1994  Winston-Salem  North Carolina                 NC
# 4        6  10/9/1995              G         Alabama                 AL
#
#      Zip  Available Points  Total Points Earned  Points Spent  \
# 0  55401               300                  300             0
# 1  97204               330                  330             0
# 2  27106             10790                14290          3500
# 3  27109               650                  650             0
# 4  85588              7085                 7395           310
#
#           Joined On           Last Seen
# 0     9/4/2020 0:15 2021-12-16 17:42:00
# 1  10/13/2020 16:20 2021-04-21 10:54:00
# ...

# %%
Zip_unique_values = df_sample['Zip'].unique()
Zip_unique_values.sort()
Zip_unique_values
# Out:
# array(['10538', '11768', '11787', '13026', '13078', '13492', '13753',
#        '14530', '15217', '19352', '19355', '19382', '1945', '2030',
#        '2067', '20814', '21093', '22213', '2332', '2478', '2493', '2532',
#        '2653', '27012', '27013', '27051', '27101', '27103', '27104',
#        '27106', '27107', '27109', '27127', '27360', '27406', '27410',
#        '27516', '27707-1634', '28078', '28079', '28097', '28115', '28117',
#        '28173', '28205', '28209', '28216', '28262', '28269', '28277',
#        '28462', '28655', '29204', '29466', '30165', '30273', '30311',
#        '30338', '32174', '32223', '32608', '33157', '33410', '33596',
#        '33908', '37204', '37205', '38112', '40222', '45174', '45419',
#        '53217', '55401', '55439', '60048', '60085', '60515', '6067',
#        '6880', '69694', '7481', '75205', '75230', '78620', '7901',
#        '80123', '8075', '85588', '88101', '90266', '92078', '93312',
#        '969', '97204'], dtype=object)

# %%
df_sample ['Zip']= df_sample['Zip'].str[:5]

# %%
Zip_unique_values = df_sample['Zip'].unique()
Zip_unique_values.sort()
Zip_unique_values
# Out:
# array(['10538', '11768', '11787', '13026', '13078', '13492', '13753',
#        '14530', '15217', '19352', '19355', '19382', '1945', '2030',
#        '2067', '20814', '21093', '22213', '2332', '2478', '2493', '2532',
#        '2653', '27012', '27013', '27051', '27101', '27103', '27104',
#        '27106', '27107', '27109', '27127', '27360', '27406', '27410',
#        '27516', '27707', '28078', '28079', '28097', '28115', '28117',
#        '28173', '28205', '28209', '28216', '28262', '28269', '28277',
#        '28462', '28655', '29204', '29466', '30165', '30273', '30311',
#        '30338', '32174', '32223', '32608', '33157', '33410', '33596',
#        '33908', '37204', '37205', '38112', '40222', '45174', '45419',
#        '53217', '55401', '55439', '60048', '60085', '60515', '6067',
#        '6880', '69694', '7481', '75205', '75230', '78620', '7901',
#        '80123', '8075', '85588', '88101', '90266', '92078', '93312',
#        '969', '97204'], dtype=object)
